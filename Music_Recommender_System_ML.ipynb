# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/spotify_millsongdata.csv", encoding='latin1')
df
# Out:
#              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                               link  \
# 0       /a/abba/ahes+my+kind+of+girl_20598417.html
# 1            /a/abba/andante+andante_20002708.html
# 2             /a/abba/as+good+as+new_20003033.html
# 3                       /a/abba/bang_20598415.html
# 4           /a/abba/bang+a+boomerang_20002668.html
# ...                                            ...
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57650 entries, 0 to 57649
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   artist  57650 non-null  object
#  1   song    57650 non-null  object
#  2   link    57650 non-null  object
#  3   text    57650 non-null  object
# dtypes: object(4)
# memory usage: 1.8+ MB

# %%
df.shape
# Out:
# (57650, 4)

# %%
df.describe()
# Out:
#               artist                                    song  \
# count          57650                                   57650
# unique           643                                   44824
# top     Donna Summer  Have Yourself A Merry Little Christmas
# freq             191                                      35
#
#                                    link  \
# count                             57650
# unique                            57650
# top     /z/zwan/heartsong_20148991.html
# freq                                  1
#
#                                                      text
# count                                               57650
# unique                                              57494
# top     I've got sunshine on a cloudy day  \r\nWhen it...
# freq                                                    6

# %%
df.isnull().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
df = df.drop('link',axis=1).reset_index(drop=True)

# %%
df['text'][0]
# Out:
# "Blasting our way through the boundaries of Hell  \r\nNo one can stop us tonight  \r\nWe take on the world with hatred inside  \r\nMayhem the reason we fight  \r\nSurviving the slaughters and killing we've lost  \r\nThen we return from the dead  \r\nAttacking once more now with twice as much strength  \r\nWe conquer then move on ahead  \r\n  \r\n[Chorus]  \r\nEvil  \r\nMy words defy  \r\nEvil  \r\nHas no disguise  \r\nEvil  \r\nWill take your soul  \r\nEvil  \r\nMy wrath unfolds  \r\n  \r\nSatan our master in evil mayhem  \r\nGuides us with every first step  \r\nOur axes are growing with power and fury  \r\nSoon there'll be nothingness left  \r\nMidnight has come and the leathers strapped on  \r\nEvil is at our command  \r\nWe clash with God's angel and conquer new souls  \r\nConsuming all that we can  \r\n  \r\n[Chorus]\r\n\r\n"

# %%
df = df.sample(5000)

# %%
df.shape
# Out:
# (5000, 3)

# %% [markdown]
# Text Cleaning / Text preprocessing

# %%
df['text'] = df['text'].str.lower().replace(r'^\w\s','').replace(r'\n',' ', regex = True)

# %%
df
# Out:
#                   artist                                   song  \
# 3277         Keith Urban                   Black Leather Jacket
# 2390            Maroon 5               Happy Xmas (War Is Over)
# 614              Misfits                       Children In Heat
# 3304   The White Stripes                            Hotel Yorba
# 3825  Horrible Histories        Victoria And Albert Love Ballad
# ...                  ...                                    ...
# 3722       Avril Lavigne                             I Love You
# 1990           Rammstein  Feuerrader (English - Wheels Of Fire)
# 1006       Grateful Dead                            Box Of Rain
# 1635           Pearl Jam                              Dissident
# 1175                INXS                       I'm Only Looking
#
#                                                    text
# 3277  i wore a black leather jacket way back in high...
# 2390  so this is christmas  \r and what have you don...
# ...

# %%
df.tail()
# Out:
#              artist                                   song  \
# 3722  Avril Lavigne                             I Love You
# 1990      Rammstein  Feuerrader (English - Wheels Of Fire)
# 1006  Grateful Dead                            Box Of Rain
# 1635      Pearl Jam                              Dissident
# 1175           INXS                       I'm Only Looking
#
#                                                    text
# 3722  la, la  \r la, la, la, la  \r la, la  \r la, l...
# 1990  put that collar on me  \r then i'll go down on...
# 1006  look out of any window  \r any morning, any ev...
# 1635  she nursed him there ooh over a night  \r i wa...
# 1175  i hear voices  \r inside my head  \r can i dec...

# %%
import nltk
from nltk.stem.porter import PorterStemmer
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
stemmer = PorterStemmer()

# %%
def token(txt):
  token = nltk.word_tokenize(txt)
  a = [stemmer.stem(w) for w in token]
  return " ".join(a)

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
token("you are beautifull, beauty")

# %%
df['text'].apply(lambda x: token(x))
# Out:
# 3277    None
# 2390    None
# 614     None
# 3304    None
# 3825    None
#         ...
# 3722    None
# 1990    None
# 1006    None
# 1635    None
# 1175    None
# Name: text, Length: 5000, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
tfid = TfidfVectorizer(analyzer='word', stop_words='english')

# %%
matrix = tfid.fit_transform(df['text'])

# %%
matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 268553 stored elements and shape (5000, 24264)>

# %%
similar = cosine_similarity(matrix)

# %%
similar[0]
# Out:
# array([1.        , 0.03300469, 0.00613679, ..., 0.02644743, 0.00246708,
#        0.00429412])

# %%
df[df['song'] == 'Black Leather Jacket'].index[0]
# Out:
# np.int64(3277)

# %% [markdown]
# Recomendor Function

# %%
def recommender(song_name):
  idx = df[df['song'] == song_name].index[0]
  distance = sorted(list(enumerate(similar[idx])), reverse=True, key=lambda x:x[1])
  song = []
  for s_id in distance[1:25]:
    song.append(df.iloc[s_id[0]].song)
  return song

# %%
recommender('Black Leather Jacket')
# Out:
# ["I Don't Care",
#  'Same Difference',
#  'The World Has Changed',
#  'You Are God',
#  'I Love Her',
#  'In My Life',
#  'As Long As You Love Me',
#  'To Be Loved',
#  'Love Me Still',
#  'Who Do You Love',
#  "You've Been In Love",
#  "Love Don't Love Nobody",
#  "You're Gonna Love Me",
#  'Without Love',
#  'A World Without Love',
#  'Love, Love, Love',
#  'The Shadows And The Wind',
#  'Love This Life',
#  'Endless Love',
#  "Love's Been Here And Gone",
#  "I Won't Give Up",
#  'Love Of My Life',
#  'I Love You',
#  'Love Machine']

# %%
import pickle

# %%
pickle.dump(similar, open("similarity","wb"))

# %%
pickle.dump(df, open("df","wb"))

# %%
df
# Out:
#                   artist                                   song  \
# 3277         Keith Urban                   Black Leather Jacket
# 2390            Maroon 5               Happy Xmas (War Is Over)
# 614              Misfits                       Children In Heat
# 3304   The White Stripes                            Hotel Yorba
# 3825  Horrible Histories        Victoria And Albert Love Ballad
# ...                  ...                                    ...
# 3722       Avril Lavigne                             I Love You
# 1990           Rammstein  Feuerrader (English - Wheels Of Fire)
# 1006       Grateful Dead                            Box Of Rain
# 1635           Pearl Jam                              Dissident
# 1175                INXS                       I'm Only Looking
#
#                                                    text
# 3277  i wore a black leather jacket way back in high...
# 2390  so this is christmas  \r and what have you don...
# ...
